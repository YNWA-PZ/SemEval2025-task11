# %%
model_name="neuralmind/bert-large-portuguese-cased"

# %%
import os

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

os.environ['WANDB_DISABLED'] = "true"

# %%
# !gdown 1qq5gDuEAqWnoviRBDYfbprLFD-MPQyNo
# !gdown 1mq9CWT9MXsH1Y-ihxVL4uEzufQjpBoer
# !gdown 1EI12smTmdi4Mlu_lLNULN6p6g9dYEWql
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1EI12smTmdi4Mlu_lLNULN6p6g9dYEWql
# To: /content/processed_data.zip
# 100% 6.00M/6.00M [00:00<00:00, 47.4MB/s]

# %%
# !rm -rf processed_data

# !unzip -q processed_data.zip

# %%
# !pip install -q transformers[torch] accelerate -U

# !pip install -q datasets

# !pip install -q transformers

# !pip install -q iterative-stratification

# !pip install -q auto-gptq optimum bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 21.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 90.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 424.1/424.1 kB 28.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 84.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.2 MB/s eta 0:00:00

# %%
import numpy as np

import pandas as pd

import os

from os import path

import glob

from tqdm.notebook import tqdm

from tqdm import tqdm

import string

import copy

from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer,IntervalStrategy,BitsAndBytesConfig

from datasets import Dataset,load_dataset, DatasetDict

# from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay



from sklearn.model_selection import train_test_split,KFold

from sklearn.metrics import classification_report,accuracy_score, f1_score

from sklearn.metrics import precision_recall_fscore_support

from sklearn.utils import shuffle

from sklearn.preprocessing import LabelEncoder

from scipy.special import expit

from peft import prepare_model_for_kbit_training

from peft import LoraConfig, get_peft_model,PeftModel

# %%
import torch

import torch.nn as nn

import torch.nn.functional as F

# %%
models_list_3=[
        model_name,
          ]



models_name_3=[
        model_name,

]

# %%
kind="train"

task="track_a"

# langs=["afr","amh","deu","eng","oro","ptbr","rus","som","sum","tir"]
# labels=['Anger','Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise']
# langs=["amh","arq","ary","chn","deu","esp","hau","hin","ibo","kin","mar","orm","pcm","ptbr","ptmz","ron","rus","som","sun","swa","swe","tat","tir","ukr","vmw","yor","ind","jav","xho","zul"]
langs=["ptbr"]
# langs=["eng"]
# langs=["afr"]


# processed_path=f"processed_data/{kinds[0]}/{tasks[0]}/{langs[3]}.csv"



# train_data=pd.read_csv(processed_path)

# %%
all_csv=pd.DataFrame()

for lang in langs:

    processed_path=f"processed_data/{kind}/{task}/{lang}.csv"
    # if kind=="dev":
    #    processed_path=processed_path.replace(lang,lang+task[-2:])
    if not os.path.isfile(processed_path):

      print("not found:",processed_path)

      continue
    train_data=pd.read_csv(processed_path)

    train_data.columns = train_data.columns.str.lower()

    all_csv = pd.concat([all_csv, train_data],ignore_index=True)

# %%
train_data=all_csv

# %%
train_data=train_data.fillna(0)

# %%
float_columns = train_data.select_dtypes(include=['float64']).columns
# Convert those columns to int
train_data[float_columns] = train_data[float_columns].astype('int')

# %%
train_data = train_data[

train_data['clean_message'].isnull()==False]

train_data.reset_index()
# Out:
#       index                        id  anger  disgust  fear  joy  sadness  \
# 0         0  ptbr_train_track_a_00001      0        0     0    0        0
# 1         1  ptbr_train_track_a_00002      1        1     0    0        0
# 2         2  ptbr_train_track_a_00003      0        0     0    1        1
# 3         3  ptbr_train_track_a_00004      1        0     0    0        0
# 4         4  ptbr_train_track_a_00005      1        0     0    0        0
# ...     ...                       ...    ...      ...   ...  ...      ...
# 2221   2221  ptbr_train_track_a_02222      1        0     0    0        0
# 2222   2222  ptbr_train_track_a_02223      0        0     0    0        0
# 2223   2223  ptbr_train_track_a_02224      1        0     1    0        1
# 2224   2224  ptbr_train_track_a_02225      0        0     0    0        0
# 2225   2225  ptbr_train_track_a_02226      0        0     0    0        0
#
#       surprise  lang                                      clean_message
# 0            0  ptbr  moça eu fiz uma análise com o tinder uma vez e...
# 1            0  ptbr  eles sempre mostram a míseria em como tudo era...
# 2            0  ptbr  eu nunca quis tanto algo como quero você jamai...
# 3            0  ptbr  esperando aqui o stf vim me emparedar do eu ex...
# 4            0  ptbr  e no final o ps vai pagar o pato ja é o 4° tre...
# ...        ...   ...                                                ...
# 2221         0  ptbr  fala fala fala mas fez pior da uma segurada ga...
# 2222         0  ptbr      lampião era um bandido ou um cidadão louvável
# 2223         0  ptbr  já somos um evangelistão sinto que voltamos a ...
# 2224         0  ptbr  sim eu ia citar isso no comentário anterior ma...
# 2225         0  ptbr  eu não posso dizer que o meu antigo namorado é...
#
# [2226 rows x 10 columns]

# %%
# label_columns =['anger', 'fear', 'joy', 'sadness', 'surprise']
label_columns =['anger', 'disgust', 'fear', 'joy', 'sadness', 'surprise']
# label_columns =['anger', 'disgust', 'fear', 'joy', 'sadness']

# %%
train_data['lang'].value_counts()
# Out:
# lang
# ptbr    2226
# Name: count, dtype: int64

# %%
sum(train_data['lang'].isna())
# Out:
# 0

# %%
nan_rows = train_data[train_data.isna().any(axis=1)]
nan_rows
# Out:
# Empty DataFrame
# Columns: [id, anger, disgust, fear, joy, sadness, surprise, lang, clean_message]
# Index: []

# %%
train_data['clean_message']=train_data['clean_message'].astype(str)

# %%
maxi=train_data['clean_message'].apply(len).max()
maxi
# Out:
# 2576

# %%
train_data[train_data['clean_message'].apply(len) == maxi]
# Out:
#                            id  anger  disgust  fear  joy  sadness  surprise  \
# 472  ptbr_train_track_a_00473      0        0     0    0        0         0
#
#      lang                                      clean_message
# 472  ptbr  o grande diferencial de um colégio não é só o ...

# %%
train_data[train_data['clean_message'].apply(len) == maxi]["clean_message"].values
# Out:
# array(['o grande diferencial de um colégio não é só o ensino mas a qualidade dos alunos que é o que vai te passar uma noção de média melhor por exemplo em um colégio excelente a média vai ser muito mas muito mais alta entre os alunos ah sim agora eu entendi o que você quis dizer sim talvez esse realmente seja o melhor dos casos mas eu fui fazer o vestibulinho pra provas de colégios desse estilo muito cedo grande parte da matéria eu acabava sem saber muito sobre e tals então atrapalha o ensino é certamente ótimo no colégio onde fui e muitos dos alunos vão bem em vestibular facilmente mas as atividades olímpicas estiveram falhando ao menos na época em que estudei também tem que mesmo sendo um ótimo colégio e renomado por ser particular e ter somente uma unidade não tem a mesma segregação que colégios objetivo ou etapa possuem a única unidade tem que englobar todos os tipos de alunos que é diferente dos exemplos onde os alunos vão para diferentes unidades praticamente baseado em seu nível acadêmico o que mais vai te levar pra frente é um ambiente onde você não é o primeiro lugar a menos que você esteja se matando pra conseguir isso aí cai o problema é que eu não quero ser o primeiro lugar e nunca quis na real eu cresci querendo ser normal então não seria necessariamente o melhor ambiente poxa talvez teria pessoas melhores para me relacionar com já que o ambiente seria diferente mas eu não necessariamente iria atrás do topo de qualquer jeito obmep obf e afins só servem pra te levar pra alguma olimpíada maior normalmente internacional onde vc realmente vai se destacar e pode até acabar conseguindo vaga em universidade do exterior com bolsa é o que eu tô tentando fazer mas eu não tenho facilidade em me aplicar individualmente a um assunto na maioria das vezes eu sempre fui um tipo de jack of all trades eu sempre soube bastante de assuntos diversos mas nunca tive um conhecimento profundo específico eu consigo aprender muito mais rápido que a pessoa média mas chega uma hora que só me cansa e eu quero ir atrás de outra coisa provavelmente um efeito colateral de ter tdah isso também faz eu conhecer melhor a parte teórica que a prática então eu sei por exemplo diversos conceitos de física quântica mas zero equações estão sob meu conhecimento eu tentei obling mas quebrei na segunda fase mas o meu colégio já teve medalhistas da oil sim por exemplo mas realmente infelizmente o ambiente nunca foi o mais propício tem gente que se destaca mas talvez seja pouco proporcional parecido com o colégio médio talvez um pouco melhor por causa do programa de bolsas'],
#       dtype=object)

# %%
# shuffle data
train_data=train_data.sample(frac=1)
# train_data=train_data.sample(100,random_state=42)

# %%
# train valid split
# train,valid=train_test_split(train_data,test_size=0.2,random_state=42)

# %%
x_train, y_train = train_data['clean_message'].values.tolist(), train_data[label_columns].values.tolist()

# %%
y_train_df = pd.DataFrame(y_train, columns=label_columns)

# %%
#update label column name

label_distribution = y_train_df.apply(pd.Series.value_counts).T.fillna(0).astype(int)

label_distribution.columns = ['count_0', 'count_1']
label_distribution['sum'] = label_distribution['count_0'] + label_distribution['count_1']
print(label_distribution)
# Out:
#           count_0  count_1   sum
# anger        1508      718  2226
# disgust      2151       75  2226
# fear         2117      109  2226
# joy          1645      581  2226
# sadness      1904      322  2226
# surprise     2073      153  2226

# %%
device="cuda" if torch.cuda.is_available() else 'cpu'

# %%
from sklearn.utils.class_weight import compute_class_weight

counts_0 = label_distribution['count_0'].to_numpy()
counts_1 = label_distribution['count_1'].to_numpy()

# Compute class-specific weights for each label (each class)
class_weights = []
for i in range(len(counts_0)):
    weight = compute_class_weight('balanced', classes=np.array([0, 1]), y=[0] * counts_0[i] + [1] * counts_1[i])
    class_weights.append(weight)

# Convert the list of weights to a tensor
class_weights_tensor = torch.tensor([w[1] for w in class_weights], dtype=torch.float,device=device)
class_weights_tensor
# Out:
# tensor([ 1.5501, 14.8400, 10.2110,  1.9157,  3.4565,  7.2745], device='cuda:0')

# %%
MAX_LENGTH = 512

metrics_df = pd.DataFrame(columns=["Models_name", "Precision", "Recall", "F1_score", "Accuracy"])

confusion_matrices = []

# %%
quantization_config = BitsAndBytesConfig(

    load_in_4bit=True,

    bnb_4bit_use_double_quant=True,

    bnb_4bit_quant_type="nf4",

    bnb_4bit_compute_dtype=torch.bfloat16,

)

# %%
models_list=models_list_3

models_name=models_name_3

x=models_list[0]

# %%
token=""

import huggingface_hub

if "gemma" in x or "Phi" in x:

  huggingface_hub.login(token=token)

# %%
USE_LORA=False

# %%
# !pip install -q sentence_transformers

# %%
from transformers import AutoModel
from sentence_transformers import SentenceTransformer

# %%
del embedding_model
for _ in range(10):
  torch.cuda.empty_cache()

# %%
torch.cuda.empty_cache()



print(x)
use_gpu = torch.cuda.is_available()
embedding_model = SentenceTransformer(
        x,
        trust_remote_code=True,
        device="cpu" if not use_gpu else "cuda",
        model_kwargs={
            "torch_dtype": torch.bfloat16 if use_gpu else torch.float32,
            # "attn_implementation": "sdpa"
        },
        # vector_dim must be 12288, 1024, 512, 256
        ## 1024 is recommended
        # set is_text_encoder 'True', if you do not encode image
        # config_kwargs={"is_text_encoder": True, "vector_dim": 1024},
    )
    # We can reduce the max_seq_length from the default of 2048 for faster encoding
embedding_model.max_seq_length = MAX_LENGTH
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name neuralmind/bert-large-portuguese-cased. Creating a new one with mean pooling.
# neuralmind/bert-large-portuguese-cased
# config.json:   0%|          | 0.00/648 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/155 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/210k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
def find_target_modules(model):
    # Initialize a Set to Store Unique Layers
    unique_layers = set()

    # Iterate Over All Named Modules in the Model
    for name, module in model.named_modules():
        # Check if the Module Type Contains 'Linear4bit'
        if "Linear4bit" in str(type(module)):
            # Extract the Type of the Layer
            layer_type = name.split('.')[-1]

            # Add the Layer Type to the Set of Unique Layers
            unique_layers.add(layer_type)

    # Return the Set of Unique Layers Converted to a List
    return list(unique_layers)
find_target_modules(embedding_model)
# Out:
# []

# %%
# a=

# %%
embedding_model.eval() # embedding_model in training mode (dropout modules are activated)

if USE_LORA:

  # enable gradient check pointing

  embedding_model.gradient_checkpointing_enable()

  target_modules_dict={

      "microsoft/Phi-3.5-mini-instruct":'all-linear',
      "unsloth/Llama-3.2-1B-Instruct":["q_proj","k_proj","v_proj"],
      "unsloth/Qwen2.5-3B-Instruct-bnb-4bit":["q_proj","k_proj","v_proj"],
  }

  target_modules= target_modules_dict.get(x,["q_proj"])



  # enable quantized training

  embedding_model = prepare_model_for_kbit_training(embedding_model)

  config = LoraConfig(

    r=8,

    lora_alpha=32,

    # target_modules=["k_proj"],

    target_modules = target_modules,#TODOOOOOOOOOOOOO

    lora_dropout=0.1,

    bias="none",

    task_type="SEQ_CLS",

  )

  # LoRA trainable version of model

  embedding_model = get_peft_model(embedding_model, config)



  # trainable parameter count

  embedding_model.print_trainable_parameters()

device="cuda" if torch.cuda.is_available() else 'cpu'

# %%
device
# Out:
# 'cuda'

# %%
embedding_model = embedding_model.to(device)

for param in embedding_model.parameters():
    param.data = param.data.contiguous()

# %%
# Custom Dataset for batching
class TextDataset(torch.utils.data.Dataset):
    def __init__(self, texts):
        self.texts = texts

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        # Tokenize a single example
        return self.texts[idx]

# %%
from torch.utils.data import DataLoader

# %%
# Batch extraction function
def extract_embeddings(texts, model, batch_size=32):
    dataset = TextDataset(texts)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

    embeddings = []
    model.eval()
    with torch.no_grad():
        for batch in tqdm(dataloader, desc="Extracting embeddings"):
            # Move batch to device
            # input_ids = torch.Tensor(batch['input_ids']).squeeze().to(device)
            # attention_mask = torch.Tensor(batch['attention_mask']).squeeze().to(device)

            # Forward pass through the model
            cls_embeddings = model.encode(batch)
            embeddings.append(cls_embeddings)

    return np.vstack(embeddings)

# %%
# Extract embeddings for train and validation datasets
x_train_embeddings = extract_embeddings(x_train, embedding_model, batch_size=32)
# Out:
# Extracting embeddings:   0%|          | 0/70 [00:00<?, ?it/s]
# Extracting embeddings:   1%|▏         | 1/70 [00:01<01:50,  1.60s/it]
# Extracting embeddings:   3%|▎         | 2/70 [00:02<01:06,  1.02it/s]
# Extracting embeddings:   4%|▍         | 3/70 [00:02<00:55,  1.21it/s]
# Extracting embeddings:   6%|▌         | 4/70 [00:03<00:46,  1.41it/s]
# Extracting embeddings:   7%|▋         | 5/70 [00:03<00:40,  1.62it/s]
# Extracting embeddings:   9%|▊         | 6/70 [00:06<01:20,  1.27s/it]
# Extracting embeddings:  10%|█         | 7/70 [00:08<01:39,  1.58s/it]
# Extracting embeddings:  11%|█▏        | 8/70 [00:09<01:35,  1.54s/it]
# Extracting embeddings:  13%|█▎        | 9/70 [00:12<01:55,  1.90s/it]
# Extracting embeddings:  14%|█▍        | 10/70 [00:14<01:43,  1.72s/it]
# Extracting embeddings:  16%|█▌        | 11/70 [00:14<01:24,  1.43s/it]
# Extracting embeddings:  17%|█▋        | 12/70 [00:16<01:34,  1.62s/it]
# Extracting embeddings:  19%|█▊        | 13/70 [00:17<01:16,  1.34s/it]
# Extracting embeddings:  20%|██        | 14/70 [00:18<01:04,  1.14s/it]
# Extracting embeddings:  21%|██▏       | 15/70 [00:18<00:54,  1.00it/s]
# Extracting embeddings:  23%|██▎       | 16/70 [00:20<00:57,  1.06s/it]
# Extracting embeddings:  24%|██▍       | 17/70 [00:21<00:54,  1.03s/it]
# Extracting embeddings:  26%|██▌       | 18/70 [00:22<00:53,  1.02s/it]
# Extracting embeddings:  27%|██▋       | 19/70 [00:22<00:48,  1.06it/s]
# Extracting embeddings:  29%|██▊       | 20/70 [00:23<00:44,  1.12it/s]
# Extracting embeddings:  30%|███       | 21/70 [00:24<00:50,  1.03s/it]
# Extracting embeddings:  31%|███▏      | 22/70 [00:25<00:44,  1.08it/s]
# Extracting embeddings:  33%|███▎      | 23/70 [00:26<00:44,  1.06it/s]
# Extracting embeddings:  34%|███▍      | 24/70 [00:27<00:40,  1.14it/s]
# Extracting embeddings:  36%|███▌      | 25/70 [00:28<00:47,  1.05s/it]
# Extracting embeddings:  37%|███▋      | 26/70 [00:29<00:39,  1.11it/s]
# Extracting embeddings:  39%|███▊      | 27/70 [00:30<00:39,  1.10it/s]
# Extracting embeddings:  40%|████      | 28/70 [00:30<00:35,  1.20it/s]
# Extracting embeddings:  41%|████▏     | 29/70 [00:32<00:37,  1.09it/s]
# Extracting embeddings:  43%|████▎     | 30/70 [00:33<00:39,  1.02it/s]
# Extracting embeddings:  44%|████▍     | 31/70 [00:34<00:40,  1.04s/it]
# Extracting embeddings:  46%|████▌     | 32/70 [00:35<00:40,  1.07s/it]
# Extracting embeddings:  47%|████▋     | 33/70 [00:36<00:34,  1.07it/s]
# Extracting embeddings:  49%|████▊     | 34/70 [00:40<01:12,  2.03s/it]
# Extracting embeddings:  50%|█████     | 35/70 [00:41<01:02,  1.77s/it]
# Extracting embeddings:  51%|█████▏    | 36/70 [00:42<00:48,  1.43s/it]
# Extracting embeddings:  53%|█████▎    | 37/70 [00:43<00:40,  1.22s/it]
# Extracting embeddings:  54%|█████▍    | 38/70 [00:43<00:32,  1.02s/it]
# Extracting embeddings:  56%|█████▌    | 39/70 [00:44<00:29,  1.06it/s]
# Extracting embeddings:  57%|█████▋    | 40/70 [00:45<00:25,  1.20it/s]
# Extracting embeddings:  59%|█████▊    | 41/70 [00:46<00:31,  1.09s/it]
# Extracting embeddings:  60%|██████    | 42/70 [00:47<00:26,  1.05it/s]
# Extracting embeddings:  61%|██████▏   | 43/70 [00:47<00:22,  1.22it/s]
# Extracting embeddings:  63%|██████▎   | 44/70 [00:48<00:19,  1.36it/s]
# Extracting embeddings:  64%|██████▍   | 45/70 [00:49<00:18,  1.38it/s]
# Extracting embeddings:  66%|██████▌   | 46/70 [00:53<00:45,  1.91s/it]
# Extracting embeddings:  67%|██████▋   | 47/70 [00:54<00:35,  1.56s/it]
# Extracting embeddings:  69%|██████▊   | 48/70 [00:55<00:26,  1.22s/it]
# Extracting embeddings:  70%|███████   | 49/70 [00:55<00:22,  1.05s/it]
# Extracting embeddings:  71%|███████▏  | 50/70 [00:57<00:23,  1.18s/it]
# Extracting embeddings:  73%|███████▎  | 51/70 [00:59<00:28,  1.50s/it]
# Extracting embeddings:  74%|███████▍  | 52/70 [01:00<00:22,  1.26s/it]
# Extracting embeddings:  76%|███████▌  | 53/70 [01:00<00:17,  1.03s/it]
# Extracting embeddings:  77%|███████▋  | 54/70 [01:01<00:13,  1.15it/s]
# Extracting embeddings:  79%|███████▊  | 55/70 [01:03<00:18,  1.26s/it]
# Extracting embeddings:  80%|████████  | 56/70 [01:04<00:16,  1.15s/it]
# Extracting embeddings:  81%|████████▏ | 57/70 [01:04<00:13,  1.05s/it]
# Extracting embeddings:  83%|████████▎ | 58/70 [01:05<00:11,  1.05it/s]
# Extracting embeddings:  84%|████████▍ | 59/70 [01:06<00:09,  1.18it/s]
# Extracting embeddings:  86%|████████▌ | 60/70 [01:07<00:08,  1.23it/s]
# Extracting embeddings:  87%|████████▋ | 61/70 [01:07<00:06,  1.35it/s]
# Extracting embeddings:  89%|████████▊ | 62/70 [01:08<00:06,  1.17it/s]
# Extracting embeddings:  90%|█████████ | 63/70 [01:09<00:05,  1.25it/s]
# Extracting embeddings:  91%|█████████▏| 64/70 [01:10<00:04,  1.28it/s]
# Extracting embeddings:  93%|█████████▎| 65/70 [01:10<00:03,  1.28it/s]
# Extracting embeddings:  94%|█████████▍| 66/70 [01:11<00:03,  1.29it/s]
# Extracting embeddings:  96%|█████████▌| 67/70 [01:12<00:02,  1.25it/s]
# Extracting embeddings:  97%|█████████▋| 68/70 [01:13<00:01,  1.18it/s]
# Extracting embeddings:  99%|█████████▊| 69/70 [01:14<00:00,  1.29it/s]
# Extracting embeddings: 100%|██████████| 70/70 [01:14<00:00,  1.07s/it]

# %%
np.save("x_train_embeddings.npy",x_train_embeddings)

# %%
# Flatten labels for XGBoost (multi-label classification)
y_train_flat = np.array(y_train)

# %%
import xgboost as xgb

# %%
# xgb_models = {}

# for i, label in enumerate(label_columns):
#     print(f"Training XGBoost for label: {label}")
#     # Use the computed class weights for the positive class
#     scale_pos_weight = class_weights_tensor[i].item()
#     # Initialize and train XGBoost classifier
#     xgb_model = xgb.XGBClassifier(
#         objective='binary:logistic',
#         eval_metric='logloss',
#         use_label_encoder=False,
#         n_estimators=100,
#         learning_rate=0.1,
#         max_depth=6,
#         tree_method='hist',
#         scale_pos_weight=scale_pos_weight,  # Apply the class weight here
#         device=device
#     )
#     xgb_model.fit(x_train_embeddings, y_train_flat[:, i])
#     xgb_models[label] = xgb_model

# %%
# Save the XGBoost models if needed
# for label, model in xgb_models.items():
#     model.save_model(f"xgb_model_{label}.json")

# %%
# import pickle
# # Save the XGBoost models if needed
# for label, model in xgb_models.items():
#     with open(f"xgb_model_{label}.pkl", 'wb') as f:
#       pickle.dump(model, f)

# %%
# !zip xgb_models_pkl.zip xgb_model_*.pkl

# %%
# !rm -rf svm*

# %%
from sklearn.svm import SVC

# %%
svm_models = {}

for i, label in enumerate(label_columns):
    print(f"Training SVM for label: {label}")

    # Use the computed class weights for balancing the classes
    class_weight = {0: 1, 1: class_weights_tensor[i].item()}  # Adjust the class weights

    svm_model = SVC(class_weight={0: 1, 1: class_weights_tensor[i].item()})

    svm_model.fit(x_train_embeddings, y_train_flat[:, i])
    svm_models[label] = svm_model
# Out:
# Training SVM for label: anger
# Training SVM for label: disgust
# Training SVM for label: fear
# Training SVM for label: joy
# Training SVM for label: sadness
# Training SVM for label: surprise

# %%
import pickle
# Save the svm models if needed
for label, model in svm_models.items():
    with open(f"svm_model_{label}.pkl", 'wb') as f:
      pickle.dump(model, f)

# %%
# !zip svm_models_pkl.zip svm_model_*.pkl
# Out:
#   adding: svm_model_anger.pkl (deflated 75%)
#   adding: svm_model_disgust.pkl (deflated 75%)
#   adding: svm_model_fear.pkl (deflated 75%)
#   adding: svm_model_joy.pkl (deflated 75%)
#   adding: svm_model_sadness.pkl (deflated 75%)
#   adding: svm_model_surprise.pkl (deflated 75%)

# %%
kind="dev"

# %%
all_csv=pd.DataFrame()

for lang in langs:

    processed_path=f"processed_data/{kind}/{task}/{lang}.csv"
    # if kind=="dev":
    #    processed_path=processed_path.replace(lang,lang+task[-2:])
    if not os.path.isfile(processed_path):

      print("not found:",processed_path)

      continue
    train_data=pd.read_csv(processed_path)

    train_data.columns = train_data.columns.str.lower()

    all_csv = pd.concat([all_csv, train_data],ignore_index=True)
dev_data=all_csv
dev_data=dev_data.fillna(0)
float_columns = dev_data.select_dtypes(include=['float64']).columns

# Convert those columns to int
dev_data[float_columns] = dev_data[float_columns].astype('int')
dev_data = dev_data[dev_data['clean_message'].isnull()==False]
dev_data.reset_index()
# Out:
#      index                      id  anger  disgust  fear  joy  sadness  \
# 0        0  ptbr_dev_track_a_00001      0        0     0    0        0
# 1        1  ptbr_dev_track_a_00002      0        0     0    0        0
# 2        2  ptbr_dev_track_a_00003      0        0     0    0        0
# 3        3  ptbr_dev_track_a_00004      0        0     0    0        0
# 4        4  ptbr_dev_track_a_00005      0        0     0    0        0
# ..     ...                     ...    ...      ...   ...  ...      ...
# 195    195  ptbr_dev_track_a_00196      0        0     0    0        0
# 196    196  ptbr_dev_track_a_00197      0        0     0    0        0
# 197    197  ptbr_dev_track_a_00198      0        0     0    0        0
# 198    198  ptbr_dev_track_a_00199      0        0     0    0        0
# 199    199  ptbr_dev_track_a_00200      0        0     0    0        0
#
#      surprise  lang                                      clean_message
# 0           0  ptbr  eu n sou o com quem vc conversava só fui mostr...
# 1           0  ptbr                           sei nem qual é mais feio
# 2           0  ptbr                              essa aqui q vou fazer
# 3           0  ptbr  eu entendi bem um pastor pede pra outro pastor...
# 4           0  ptbr                                 tá muito linda pqp
# ..        ...   ...                                                ...
# 195         0  ptbr  sempre irão aparecer pessoas assim mas cabe a ...
# 196         0  ptbr                              corno pra fazer a boa
# 197         0  ptbr  ai vi tua irmã ontem mas eu tava mt louca na h...
# 198         0  ptbr  hoje o dia está lindo perfeito para levar um t...
# 199         0  ptbr  essa vai ser outra frase pra silenciar puta me...
#
# [200 rows x 10 columns]

# %%
x_dev, y_dev = dev_data['clean_message'].values.tolist(), dev_data[label_columns].values.tolist()

# %%
y_dev_df = pd.DataFrame(y_dev, columns=label_columns)

# %%
x_dev_embeddings = extract_embeddings(x_dev, embedding_model, batch_size=32)
# Out:
# Extracting embeddings: 100%|██████████| 7/7 [00:04<00:00,  1.48it/s]

# %%
y_dev_flat = np.array(y_dev)

# %%
# Predict labels for the test data
test_predictions = {}
for label in label_columns:
    print(f"Predicting for label: {label}")
    test_predictions[label] = svm_models[label].predict(x_dev_embeddings)
# Out:
# Predicting for label: anger
# Predicting for label: disgust
# Predicting for label: fear
# Predicting for label: joy
# Predicting for label: sadness
# Predicting for label: surprise

# %%
predictions_df = pd.DataFrame(test_predictions)
dev_data.reset_index(inplace=True)

# %%
output_df = pd.concat([dev_data[['id','lang']], predictions_df], axis=1)

# %%
# !rm -rf track*

# %%
# Create directory if it doesn't exist
output_dir = task
os.makedirs(output_dir, exist_ok=True)

# Iterate through the unique languages in the 'lang' column
for lang in output_df['lang'].unique():
    # Filter rows for the current language
    lang_df = output_df[output_df['lang'] == lang]
    lang_df.drop(columns=['lang'],inplace=True)

    # Define the output file path for the current language
    lang_csv_file = os.path.join(output_dir, f"pred_{lang}.csv")

    # Sort the DataFrame by the 'id' column
    lang_df.sort_values(by='id', inplace=True)

    # Save the filtered DataFrame to a CSV file
    lang_df.to_csv(lang_csv_file, index=False)

    # Print a confirmation message
    print(f"Predictions for language '{lang}' saved to {lang_csv_file}")
# Out:
# Predictions for language 'ptbr' saved to track_a/pred_ptbr.csv

# %%
# !zip -r {task}.zip {task}
# Out:
#   adding: track_a/ (stored 0%)
#   adding: track_a/pred_ptbr.csv (deflated 90%)
