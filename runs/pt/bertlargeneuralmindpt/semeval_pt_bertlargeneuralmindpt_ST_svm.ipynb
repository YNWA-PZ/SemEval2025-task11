# %%
import os

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

os.environ['WANDB_DISABLED'] = "true"

# %%
# !gdown 1qq5gDuEAqWnoviRBDYfbprLFD-MPQyNo
# !gdown 1mq9CWT9MXsH1Y-ihxVL4uEzufQjpBoer
# !gdown 1EI12smTmdi4Mlu_lLNULN6p6g9dYEWql
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1EI12smTmdi4Mlu_lLNULN6p6g9dYEWql
# To: /content/processed_data.zip
# 100% 6.00M/6.00M [00:00<00:00, 100MB/s]

# %%
# !rm -rf processed_data

# !unzip -q processed_data.zip

# %%
# !pip install -q transformers[torch] accelerate -U

# !pip install -q datasets

# !pip install -q transformers

# !pip install -q iterative-stratification

# !pip install -q auto-gptq optimum bitsandbytes

# %%
import numpy as np

import pandas as pd

import os

from os import path

import glob

from tqdm.notebook import tqdm

from tqdm import tqdm

import string

import copy

from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer,IntervalStrategy,BitsAndBytesConfig

from datasets import Dataset,load_dataset, DatasetDict

# from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay



from sklearn.model_selection import train_test_split,KFold

from sklearn.metrics import classification_report,accuracy_score, f1_score

from sklearn.metrics import precision_recall_fscore_support

from sklearn.utils import shuffle

from sklearn.preprocessing import LabelEncoder

from scipy.special import expit

from peft import prepare_model_for_kbit_training

from peft import LoraConfig, get_peft_model,PeftModel

# %%
import torch

import torch.nn as nn

import torch.nn.functional as F

# %%
models_list_3=[
        # "FacebookAI/xlm-roberta-large",
      # "google-bert/bert-base-uncased",
        "neuralmind/bert-large-portuguese-cased",

#      "google-bert/bert-base-multilingual-uncased",

          ]



models_name_3=[
# "FacebookAI/xlm-roberta-large",
# "google-bert/bert-base-uncased",
        "neuralmind/bert-large-portuguese-cased",

# "bert",

]

# %%
kind="train"

task="track_a"

# langs=["afr","amh","deu","eng","oro","ptbr","rus","som","sum","tir"]
# labels=['Anger','Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise']
# langs=["amh","arq","ary","chn","deu","esp","hau","hin","ibo","kin","mar","orm","pcm","ptbr","ptmz","ron","rus","som","sun","swa","swe","tat","tir","ukr","vmw","yor","ind","jav","xho","zul"]
langs=["ptbr","ptmz"]
# langs=["afr"]


# processed_path=f"processed_data/{kinds[0]}/{tasks[0]}/{langs[3]}.csv"



# train_data=pd.read_csv(processed_path)

# %%
all_csv=pd.DataFrame()

for lang in langs:

    processed_path=f"processed_data/{kind}/{task}/{lang}.csv"
    # if kind=="dev":
    #    processed_path=processed_path.replace(lang,lang+task[-2:])
    if not os.path.isfile(processed_path):

      print("not found:",processed_path)

      continue
    train_data=pd.read_csv(processed_path)

    train_data.columns = train_data.columns.str.lower()

    all_csv = pd.concat([all_csv, train_data],ignore_index=True)

# %%
all_csv
# Out:
#                             id  anger  disgust  fear  joy  sadness  surprise  \
# 0     ptbr_train_track_a_00001      0        0     0    0        0         0
# 1     ptbr_train_track_a_00002      1        1     0    0        0         0
# 2     ptbr_train_track_a_00003      0        0     0    1        1         0
# 3     ptbr_train_track_a_00004      1        0     0    0        0         0
# 4     ptbr_train_track_a_00005      1        0     0    0        0         0
# ...                        ...    ...      ...   ...  ...      ...       ...
# 3767  ptmz_train_track_a_01542      0        0     0    1        0         0
# 3768  ptmz_train_track_a_01543      0        0     0    1        0         0
# 3769  ptmz_train_track_a_01544      0        0     0    0        0         0
# 3770  ptmz_train_track_a_01545      0        0     0    0        0         0
# 3771  ptmz_train_track_a_01546      0        0     0    1        0         0
#
#       lang                                      clean_message
# 0     ptbr  moça eu fiz uma análise com o tinder uma vez e...
# 1     ptbr  eles sempre mostram a míseria em como tudo era...
# 2     ptbr  eu nunca quis tanto algo como quero você jamai...
# 3     ptbr  esperando aqui o stf vim me emparedar do eu ex...
# 4     ptbr  e no final o ps vai pagar o pato ja é o 4° tre...
# ...    ...                                                ...
# 3767  ptmz        salários mínimos vão aumentar em moçambique
# 3768  ptmz  covid19 organizações da sociedade civil engaja...
# 3769  ptmz  friagem atinge a amazônia peruana consequência...
# 3770  ptmz  can 2021 favoritos ganham por vantagem mínima ...
# 3771  ptmz  com álbum de figurinhas em alta peruanos comem...
#
# [3772 rows x 9 columns]

# %%
all_csv[all_csv["lang"]=="eng"]
# Out:
# Empty DataFrame
# Columns: [id, anger, disgust, fear, joy, sadness, surprise, lang, clean_message]
# Index: []

# %%
# float_columns = all_csv.select_dtypes(include=['float64']).columns
# # Check each column and convert only if there are no NaN values
# for col in float_columns:
#     if all_csv[col].isna().sum() == 0:  # No NaN values in the column
#         print(f"converting {kind} {task} {lang} column {col} to int")
#         all_csv[col] = all_csv[col].astype('int')
#     else:
#         print(f"converting {kind} {task} {lang} column {col} to int")

# %%
train_data=all_csv

# %%
# train_data = train_data.drop(columns=['disgust'],axis=1)

# %%
train_data=train_data.fillna(0)

train_data
# Out:
#                             id  anger  disgust  fear  joy  sadness  surprise  \
# 0     ptbr_train_track_a_00001      0        0     0    0        0         0
# 1     ptbr_train_track_a_00002      1        1     0    0        0         0
# 2     ptbr_train_track_a_00003      0        0     0    1        1         0
# 3     ptbr_train_track_a_00004      1        0     0    0        0         0
# 4     ptbr_train_track_a_00005      1        0     0    0        0         0
# ...                        ...    ...      ...   ...  ...      ...       ...
# 3767  ptmz_train_track_a_01542      0        0     0    1        0         0
# 3768  ptmz_train_track_a_01543      0        0     0    1        0         0
# 3769  ptmz_train_track_a_01544      0        0     0    0        0         0
# 3770  ptmz_train_track_a_01545      0        0     0    0        0         0
# 3771  ptmz_train_track_a_01546      0        0     0    1        0         0
#
#       lang                                      clean_message
# 0     ptbr  moça eu fiz uma análise com o tinder uma vez e...
# 1     ptbr  eles sempre mostram a míseria em como tudo era...
# 2     ptbr  eu nunca quis tanto algo como quero você jamai...
# 3     ptbr  esperando aqui o stf vim me emparedar do eu ex...
# 4     ptbr  e no final o ps vai pagar o pato ja é o 4° tre...
# ...    ...                                                ...
# 3767  ptmz        salários mínimos vão aumentar em moçambique
# 3768  ptmz  covid19 organizações da sociedade civil engaja...
# 3769  ptmz  friagem atinge a amazônia peruana consequência...
# 3770  ptmz  can 2021 favoritos ganham por vantagem mínima ...
# 3771  ptmz  com álbum de figurinhas em alta peruanos comem...
#
# [3772 rows x 9 columns]

# %%
float_columns = train_data.select_dtypes(include=['float64']).columns

# Convert those columns to int
train_data[float_columns] = train_data[float_columns].astype('int')
train_data
# Out:
#                             id  anger  disgust  fear  joy  sadness  surprise  \
# 0     ptbr_train_track_a_00001      0        0     0    0        0         0
# 1     ptbr_train_track_a_00002      1        1     0    0        0         0
# 2     ptbr_train_track_a_00003      0        0     0    1        1         0
# 3     ptbr_train_track_a_00004      1        0     0    0        0         0
# 4     ptbr_train_track_a_00005      1        0     0    0        0         0
# ...                        ...    ...      ...   ...  ...      ...       ...
# 3767  ptmz_train_track_a_01542      0        0     0    1        0         0
# 3768  ptmz_train_track_a_01543      0        0     0    1        0         0
# 3769  ptmz_train_track_a_01544      0        0     0    0        0         0
# 3770  ptmz_train_track_a_01545      0        0     0    0        0         0
# 3771  ptmz_train_track_a_01546      0        0     0    1        0         0
#
#       lang                                      clean_message
# 0     ptbr  moça eu fiz uma análise com o tinder uma vez e...
# 1     ptbr  eles sempre mostram a míseria em como tudo era...
# 2     ptbr  eu nunca quis tanto algo como quero você jamai...
# 3     ptbr  esperando aqui o stf vim me emparedar do eu ex...
# 4     ptbr  e no final o ps vai pagar o pato ja é o 4° tre...
# ...    ...                                                ...
# 3767  ptmz        salários mínimos vão aumentar em moçambique
# 3768  ptmz  covid19 organizações da sociedade civil engaja...
# 3769  ptmz  friagem atinge a amazônia peruana consequência...
# 3770  ptmz  can 2021 favoritos ganham por vantagem mínima ...
# 3771  ptmz  com álbum de figurinhas em alta peruanos comem...
#
# [3772 rows x 9 columns]

# %%
train_data.dtypes
# Out:
# id               object
# anger             int64
# disgust           int64
# fear              int64
# joy               int64
# sadness           int64
# surprise          int64
# lang             object
# clean_message    object
# dtype: object

# %%
train_data = train_data[

train_data['clean_message'].isnull()==False]

train_data.reset_index()
# Out:
#       index                        id  anger  disgust  fear  joy  sadness  \
# 0         0  ptbr_train_track_a_00001      0        0     0    0        0
# 1         1  ptbr_train_track_a_00002      1        1     0    0        0
# 2         2  ptbr_train_track_a_00003      0        0     0    1        1
# 3         3  ptbr_train_track_a_00004      1        0     0    0        0
# 4         4  ptbr_train_track_a_00005      1        0     0    0        0
# ...     ...                       ...    ...      ...   ...  ...      ...
# 3767   3767  ptmz_train_track_a_01542      0        0     0    1        0
# 3768   3768  ptmz_train_track_a_01543      0        0     0    1        0
# 3769   3769  ptmz_train_track_a_01544      0        0     0    0        0
# 3770   3770  ptmz_train_track_a_01545      0        0     0    0        0
# 3771   3771  ptmz_train_track_a_01546      0        0     0    1        0
#
#       surprise  lang                                      clean_message
# 0            0  ptbr  moça eu fiz uma análise com o tinder uma vez e...
# 1            0  ptbr  eles sempre mostram a míseria em como tudo era...
# 2            0  ptbr  eu nunca quis tanto algo como quero você jamai...
# 3            0  ptbr  esperando aqui o stf vim me emparedar do eu ex...
# 4            0  ptbr  e no final o ps vai pagar o pato ja é o 4° tre...
# ...        ...   ...                                                ...
# 3767         0  ptmz        salários mínimos vão aumentar em moçambique
# 3768         0  ptmz  covid19 organizações da sociedade civil engaja...
# 3769         0  ptmz  friagem atinge a amazônia peruana consequência...
# 3770         0  ptmz  can 2021 favoritos ganham por vantagem mínima ...
# 3771         0  ptmz  com álbum de figurinhas em alta peruanos comem...
#
# [3772 rows x 10 columns]

# %%
train_data
# Out:
#                             id  anger  disgust  fear  joy  sadness  surprise  \
# 0     ptbr_train_track_a_00001      0        0     0    0        0         0
# 1     ptbr_train_track_a_00002      1        1     0    0        0         0
# 2     ptbr_train_track_a_00003      0        0     0    1        1         0
# 3     ptbr_train_track_a_00004      1        0     0    0        0         0
# 4     ptbr_train_track_a_00005      1        0     0    0        0         0
# ...                        ...    ...      ...   ...  ...      ...       ...
# 3767  ptmz_train_track_a_01542      0        0     0    1        0         0
# 3768  ptmz_train_track_a_01543      0        0     0    1        0         0
# 3769  ptmz_train_track_a_01544      0        0     0    0        0         0
# 3770  ptmz_train_track_a_01545      0        0     0    0        0         0
# 3771  ptmz_train_track_a_01546      0        0     0    1        0         0
#
#       lang                                      clean_message
# 0     ptbr  moça eu fiz uma análise com o tinder uma vez e...
# 1     ptbr  eles sempre mostram a míseria em como tudo era...
# 2     ptbr  eu nunca quis tanto algo como quero você jamai...
# 3     ptbr  esperando aqui o stf vim me emparedar do eu ex...
# 4     ptbr  e no final o ps vai pagar o pato ja é o 4° tre...
# ...    ...                                                ...
# 3767  ptmz        salários mínimos vão aumentar em moçambique
# 3768  ptmz  covid19 organizações da sociedade civil engaja...
# 3769  ptmz  friagem atinge a amazônia peruana consequência...
# 3770  ptmz  can 2021 favoritos ganham por vantagem mínima ...
# 3771  ptmz  com álbum de figurinhas em alta peruanos comem...
#
# [3772 rows x 9 columns]

# %%
# label_columns =['anger', 'fear', 'joy', 'sadness', 'surprise']
label_columns =['anger', 'disgust', 'fear', 'joy', 'sadness', 'surprise']

# %%
train_data['lang'].value_counts()
# Out:
# lang
# ptbr    2226
# ptmz    1546
# Name: count, dtype: int64

# %%
sum(train_data['lang'].isna())
# Out:
# 0

# %%
nan_rows = train_data[train_data.isna().any(axis=1)]
nan_rows
# Group by 'lang' and list the rows with NaNs for each language
# nan_by_language = nan_rows.groupby('lang').apply(lambda x: x)

# Display the result
# print(nan_by_language)
# Out:
# Empty DataFrame
# Columns: [id, anger, disgust, fear, joy, sadness, surprise, lang, clean_message]
# Index: []

# %%
nan_rows[nan_rows["lang"]=="eng"]
# Out:
# Empty DataFrame
# Columns: [id, anger, disgust, fear, joy, sadness, surprise, lang, clean_message]
# Index: []

# %%
train_data[train_data["lang"]=="deu"].dtypes
# Out:
# id               object
# anger             int64
# disgust           int64
# fear              int64
# joy               int64
# sadness           int64
# surprise          int64
# lang             object
# clean_message    object
# dtype: object

# %%
nan_rows["lang"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
nan_rows.dtypes
# Out:
# id               object
# anger             int64
# disgust           int64
# fear              int64
# joy               int64
# sadness           int64
# surprise          int64
# lang             object
# clean_message    object
# dtype: object

# %%
# Step 2: Count how many columns are not 0 or 1 for each language
def count_nonzero_nonone_rows(group):
    # Exclude the 'lang' column from counting if needed
    # Use boolean conditions to count values that are not 0 or 1
    return (group.drop(columns='anger') != 0) & (group.drop(columns='anger') != 1).sum(axis=1).sum()

# Group by 'lang' and apply the function to count non-zero, non-one values
non_zero_non_one_counts = train_data.groupby('lang').apply(count_nonzero_nonone_rows)

# Display the results
# result = pd.DataFrame({
#     'row_count': lang_row_counts,
#     'non_zero_non_one_count': non_zero_non_one_counts
# })

print(non_zero_non_one_counts)
# Out:
#               id  disgust   fear    joy  sadness  surprise   lang  \
# lang
# ptbr 0     False    False  False  False    False     False  False
#      1     False    False  False  False    False     False  False
#      2     False    False  False  False    False     False  False
#      3     False    False  False  False    False     False  False
#      4     False    False  False  False    False     False  False
# ...          ...      ...    ...    ...      ...       ...    ...
# ptmz 3767  False    False  False  False    False     False  False
#      3768  False    False  False  False    False     False  False
#      3769  False    False  False  False    False     False  False
#      3770  False    False  False  False    False     False  False
#      3771  False    False  False  False    False     False  False
#
#            clean_message
# lang
# ptbr 0             False
#      1             False
#      2             False
#      3             False
#      4             False
# ...                  ...
# ptmz 3767          False
#      3768          False
#      3769          False
#      3770          False
#      3771          False
#
# [3772 rows x 8 columns]
# <ipython-input-276-06fbda4bf1b6>:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   non_zero_non_one_counts = train_data.groupby('lang').apply(count_nonzero_nonone_rows)

# %%
maxi=train_data['clean_message'].apply(len).max()
maxi
# Out:
# 2576

# %%
train_data[train_data['clean_message'].apply(len) == maxi]
# Out:
#                            id  anger  disgust  fear  joy  sadness  surprise  \
# 472  ptbr_train_track_a_00473      0        0     0    0        0         0
#
#      lang                                      clean_message
# 472  ptbr  o grande diferencial de um colégio não é só o ...

# %%
train_data[train_data['clean_message'].apply(len) == maxi]["clean_message"].values
# Out:
# array(['o grande diferencial de um colégio não é só o ensino mas a qualidade dos alunos que é o que vai te passar uma noção de média melhor por exemplo em um colégio excelente a média vai ser muito mas muito mais alta entre os alunos ah sim agora eu entendi o que você quis dizer sim talvez esse realmente seja o melhor dos casos mas eu fui fazer o vestibulinho pra provas de colégios desse estilo muito cedo grande parte da matéria eu acabava sem saber muito sobre e tals então atrapalha o ensino é certamente ótimo no colégio onde fui e muitos dos alunos vão bem em vestibular facilmente mas as atividades olímpicas estiveram falhando ao menos na época em que estudei também tem que mesmo sendo um ótimo colégio e renomado por ser particular e ter somente uma unidade não tem a mesma segregação que colégios objetivo ou etapa possuem a única unidade tem que englobar todos os tipos de alunos que é diferente dos exemplos onde os alunos vão para diferentes unidades praticamente baseado em seu nível acadêmico o que mais vai te levar pra frente é um ambiente onde você não é o primeiro lugar a menos que você esteja se matando pra conseguir isso aí cai o problema é que eu não quero ser o primeiro lugar e nunca quis na real eu cresci querendo ser normal então não seria necessariamente o melhor ambiente poxa talvez teria pessoas melhores para me relacionar com já que o ambiente seria diferente mas eu não necessariamente iria atrás do topo de qualquer jeito obmep obf e afins só servem pra te levar pra alguma olimpíada maior normalmente internacional onde vc realmente vai se destacar e pode até acabar conseguindo vaga em universidade do exterior com bolsa é o que eu tô tentando fazer mas eu não tenho facilidade em me aplicar individualmente a um assunto na maioria das vezes eu sempre fui um tipo de jack of all trades eu sempre soube bastante de assuntos diversos mas nunca tive um conhecimento profundo específico eu consigo aprender muito mais rápido que a pessoa média mas chega uma hora que só me cansa e eu quero ir atrás de outra coisa provavelmente um efeito colateral de ter tdah isso também faz eu conhecer melhor a parte teórica que a prática então eu sei por exemplo diversos conceitos de física quântica mas zero equações estão sob meu conhecimento eu tentei obling mas quebrei na segunda fase mas o meu colégio já teve medalhistas da oil sim por exemplo mas realmente infelizmente o ambiente nunca foi o mais propício tem gente que se destaca mas talvez seja pouco proporcional parecido com o colégio médio talvez um pouco melhor por causa do programa de bolsas'],
#       dtype=object)

# %%
# shuffle data
train_data=train_data.sample(frac=1)
# train_data=train_data.sample(100,random_state=42)

# %%
# train valid split
train,valid=train_test_split(train_data,test_size=0.2,random_state=42)

# %%
x_train, y_train = train['clean_message'].values.tolist(), train[label_columns].values.tolist()

x_valid, y_valid = valid['clean_message'].values.tolist(), valid[label_columns].values.tolist()

# %%
y_train_df = pd.DataFrame(y_train, columns=label_columns)

# %%
#update label column name

label_distribution = y_train_df.apply(pd.Series.value_counts).T.fillna(0).astype(int)

label_distribution.columns = ['count_0', 'count_1']
label_distribution['sum'] = label_distribution['count_0'] + label_distribution['count_1']
print(label_distribution)
# Out:
#           count_0  count_1   sum
# anger        2368      649  3017
# disgust      2910      107  3017
# fear         2839      178  3017
# joy          2394      623  3017
# sadness      2539      478  3017
# surprise     2809      208  3017

# %%
device="cuda" if torch.cuda.is_available() else 'cpu'

# %%
from sklearn.utils.class_weight import compute_class_weight

counts_0 = label_distribution['count_0'].to_numpy()
counts_1 = label_distribution['count_1'].to_numpy()

# Compute class-specific weights for each label (each class)
class_weights = []
for i in range(len(counts_0)):
    weight = compute_class_weight('balanced', classes=np.array([0, 1]), y=[0] * counts_0[i] + [1] * counts_1[i])
    class_weights.append(weight)

# Convert the list of weights to a tensor
class_weights_tensor = torch.tensor([w[1] for w in class_weights], dtype=torch.float,device=device)
class_weights_tensor
# Out:
# tensor([ 2.3243, 14.0981,  8.4747,  2.4213,  3.1559,  7.2524], device='cuda:0')

# %%
class Dataset(torch.utils.data.Dataset):

    def __init__(self, encodings, labels):

        self.encodings = encodings

        self.labels = labels



    def __getitem__(self, idx):

        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}

        item['labels'] = torch.tensor(self.labels[idx], dtype=torch.float)

        return item


    def __len__(self):

        return len(self.labels)

# %%
# !ls output/best-model-v1
# Out:
# ls: cannot access 'output/best-model-v1': No such file or directory

# %%
def build_dataset(x_train,y_train,x_valid,y_valid,MAX_LENGTH):

  train_encodings = tokenizer(x_train, truncation=True, padding="max_length", max_length=MAX_LENGTH)

  valid_encodings = tokenizer(x_valid, truncation=True, padding="max_length", max_length=MAX_LENGTH)

  train_dataset = Dataset(train_encodings, y_train)

  valid_dataset = Dataset(valid_encodings, y_valid)

  return train_dataset,valid_dataset



def train_arg():

    training_args = TrainingArguments(

    output_dir="./output/best-model-v1",

    report_to=None,
    dataloader_pin_memory=False,

    num_train_epochs=3,

    gradient_accumulation_steps=2,

    per_device_train_batch_size=8,

    per_device_eval_batch_size=16,

    learning_rate=2e-5,

    weight_decay=0.01,

    eval_strategy=IntervalStrategy.STEPS,

    save_total_limit=1,

    logging_dir="./logs",

    logging_strategy=IntervalStrategy.STEPS,

    logging_steps=250,

    eval_steps=500,

    load_best_model_at_end=True,

    lr_scheduler_type="cosine_with_restarts",

    warmup_steps=500,

    save_strategy="steps",

    save_steps=500,

  )

    return training_args

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import numpy as np

def compute_metrics(eval_pred):
    """
    Compute metrics for multi-label classification.

    Args:
        eval_pred: Tuple of (predictions, labels).
            predictions: logits or probabilities of shape (batch_size, num_labels)
            labels: ground truth of shape (batch_size, num_labels)

    Returns:
        metrics: Dictionary containing accuracy, precision, recall, and F1-score.
    """
    # Unpack predictions and labels
    logits, labels = eval_pred

    # Convert logits to binary predictions
    # If your model outputs probabilities (e.g., after sigmoid), use threshold=0.5
    probabilities = expit(logits)
    predictions = (probabilities > 0.5).astype(int)

    # Compute accuracy
    accuracy = accuracy_score(labels, predictions)

    # Compute precision, recall, f1-score
    precision, recall, f1, _ = precision_recall_fscore_support(
        labels, predictions, average=None
    )

    return {
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1": f1
    }

# %%
import torch
from torch.utils.data import DataLoader
from tqdm import tqdm
from scipy.special import expit  # For sigmoid activation if needed

def evaluate_model(model, valid_dataset, compute_metrics, batch_size=32, device="cuda",average=None):
    """
    Evaluate a multi-label classification model without using the Hugging Face Trainer.

    Args:
        model: The trained model (Hugging Face model).
        valid_dataset: The validation dataset (torch.utils.data.Dataset).
        compute_metrics: The function to compute evaluation metrics.
        batch_size: Batch size for evaluation.
        device: Device to perform evaluation (e.g., "cuda" or "cpu").

    Returns:
        metrics: Dictionary containing evaluation metrics.
    """
    # Set model to evaluation mode
    model.eval()
    model.to(device)

    # Create DataLoader for the validation dataset
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

    all_predictions = []
    all_labels = []

    # Disable gradient computation for evaluation
    with torch.no_grad():
        for batch in tqdm(valid_loader, desc="Evaluating"):
            # Get inputs and labels
            inputs = {key: val.to(device) for key, val in batch.items() if key != "labels"}
            labels = batch["labels"].to(device)

            # Forward pass: Get logits
            logits = model(**inputs)

            # Apply sigmoid activation to logits if necessary (for multi-label classification)
            probabilities = expit(logits.cpu().numpy())  # Convert logits to probabilities
            predictions = (probabilities > 0.5).astype(int)  # Convert probabilities to binary predictions

            # Collect predictions and labels
            all_predictions.append(predictions)
            all_labels.append(labels.cpu().numpy())
    print()
    # Concatenate all predictions and labels
    all_predictions = np.concatenate(all_predictions, axis=0)
    all_labels = np.concatenate(all_labels, axis=0)

    # Unpack predictions and labels
    logits, labels = all_predictions,all_labels

    # Convert logits to binary predictions
    # If your model outputs probabilities (e.g., after sigmoid), use threshold=0.5
    probabilities = expit(logits)
    predictions = (probabilities > 0.5).astype(int)

    # Compute accuracy
    accuracy = accuracy_score(labels, predictions)

    # Compute precision, recall, f1-score
    precision, recall, f1, _ = precision_recall_fscore_support(
        labels, predictions, average=average
    )
    return {
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1": f1
    },all_predictions

# %%
def evaluate_func(trainer):
    metrics = evaluate_model(
    model=model,
    valid_dataset=valid_dataset,
    compute_metrics=compute_metrics,
    batch_size=32,
    device=device
)
    accuracy=metrics["accuracy"]
    precision=metrics["precision"]
    recall=metrics["recall"]
    f1=metrics["f1"]

    return precision, recall, f1, accuracy

# %%
MAX_LENGTH = 512

metrics_df = pd.DataFrame(columns=["Models_name", "Precision", "Recall", "F1_score", "Accuracy"])

confusion_matrices = []

# %%
quantization_config = BitsAndBytesConfig(

    load_in_4bit=True,

    bnb_4bit_use_double_quant=True,

    bnb_4bit_quant_type="nf4",

    bnb_4bit_compute_dtype=torch.bfloat16,

)

# %%
models_list=models_list_3

models_name=models_name_3

x=models_list[0]

# %%
token=""

import huggingface_hub

if "gemma" in x or "Phi" in x:

  huggingface_hub.login(token=token)

# %%
USE_LORA=False

# %%
from transformers import AutoModel
from sentence_transformers import SentenceTransformer

# %%
torch.cuda.empty_cache()



print(x)
use_gpu = torch.cuda.is_available()
embedding_model = SentenceTransformer(
        x,
        trust_remote_code=True,
        device="cpu" if not use_gpu else "cuda",
        model_kwargs={
            "torch_dtype": torch.bfloat16 if use_gpu else torch.float32,
            # "attn_implementation": "sdpa"
        },
        # vector_dim must be 12288, 1024, 512, 256
        ## 1024 is recommended
        # set is_text_encoder 'True', if you do not encode image
        # config_kwargs={"is_text_encoder": True, "vector_dim": 1024},
    )
    # We can reduce the max_seq_length from the default of 2048 for faster encoding
embedding_model.max_seq_length = MAX_LENGTH
# Out:
# neuralmind/bert-large-portuguese-cased
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name neuralmind/bert-large-portuguese-cased. Creating a new one with mean pooling.
# config.json:   0%|          | 0.00/648 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/155 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/210k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
def find_target_modules(model):
    # Initialize a Set to Store Unique Layers
    unique_layers = set()

    # Iterate Over All Named Modules in the Model
    for name, module in model.named_modules():
        # Check if the Module Type Contains 'Linear4bit'
        if "Linear4bit" in str(type(module)):
            # Extract the Type of the Layer
            layer_type = name.split('.')[-1]

            # Add the Layer Type to the Set of Unique Layers
            unique_layers.add(layer_type)

    # Return the Set of Unique Layers Converted to a List
    return list(unique_layers)
find_target_modules(embedding_model)
# Out:
# []

# %%
# a=

# %%
embedding_model.eval() # embedding_model in training mode (dropout modules are activated)

if USE_LORA:

  # enable gradient check pointing

  embedding_model.gradient_checkpointing_enable()

  target_modules_dict={

      "microsoft/Phi-3.5-mini-instruct":'all-linear',
      "unsloth/Llama-3.2-1B-Instruct":["q_proj","k_proj","v_proj"],
      "unsloth/Qwen2.5-3B-Instruct-bnb-4bit":["q_proj","k_proj","v_proj"],
  }

  target_modules= target_modules_dict.get(x,["q_proj"])



  # enable quantized training

  embedding_model = prepare_model_for_kbit_training(embedding_model)

  config = LoraConfig(

    r=8,

    lora_alpha=32,

    # target_modules=["k_proj"],

    target_modules = target_modules,#TODOOOOOOOOOOOOO

    lora_dropout=0.1,

    bias="none",

    task_type="SEQ_CLS",

  )

  # LoRA trainable version of model

  embedding_model = get_peft_model(embedding_model, config)



  # trainable parameter count

  embedding_model.print_trainable_parameters()

device="cuda" if torch.cuda.is_available() else 'cpu'

# %%
device
# Out:
# 'cuda'

# %%
embedding_model = embedding_model.to(device)

for param in embedding_model.parameters():
    param.data = param.data.contiguous()

# %%
# Custom Dataset for batching
class TextDataset(Dataset):
    def __init__(self, texts):
        self.texts = texts

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        # Tokenize a single example
        return self.texts[idx]
        # return self.tokenizer(
        #     self.texts[idx],
        #     truncation=True,
        #     padding="max_length",
        #     max_length=self.max_length,
        #     return_tensors="pt"
        # )

# %%
# Batch extraction function
def extract_embeddings(texts, model, batch_size=32):
    dataset = TextDataset(texts)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

    embeddings = []
    model.eval()
    with torch.no_grad():
        for batch in tqdm(dataloader, desc="Extracting embeddings"):
            # Move batch to device
            # input_ids = torch.Tensor(batch['input_ids']).squeeze().to(device)
            # attention_mask = torch.Tensor(batch['attention_mask']).squeeze().to(device)

            # Forward pass through the model
            cls_embeddings = model.encode(batch)
            embeddings.append(cls_embeddings)

    return np.vstack(embeddings)

# %%
# Extract embeddings for train and validation datasets
x_train_embeddings = extract_embeddings(x_train, embedding_model, batch_size=32)
x_valid_embeddings = extract_embeddings(x_valid, embedding_model, batch_size=32)
# Out:
# Extracting embeddings:   0%|          | 0/95 [00:00<?, ?it/s]
# Extracting embeddings:   1%|          | 1/95 [00:00<00:58,  1.62it/s]
# Extracting embeddings:   2%|▏         | 2/95 [00:00<00:42,  2.16it/s]
# Extracting embeddings:   3%|▎         | 3/95 [00:01<00:48,  1.90it/s]
# Extracting embeddings:   4%|▍         | 4/95 [00:02<00:45,  1.99it/s]
# Extracting embeddings:   5%|▌         | 5/95 [00:02<00:43,  2.08it/s]
# Extracting embeddings:   6%|▋         | 6/95 [00:03<00:45,  1.96it/s]
# Extracting embeddings:   7%|▋         | 7/95 [00:03<00:48,  1.82it/s]
# Extracting embeddings:   8%|▊         | 8/95 [00:04<00:46,  1.88it/s]
# Extracting embeddings:   9%|▉         | 9/95 [00:04<00:45,  1.88it/s]
# Extracting embeddings:  11%|█         | 10/95 [00:05<01:00,  1.41it/s]
# Extracting embeddings:  12%|█▏        | 11/95 [00:10<02:31,  1.80s/it]
# Extracting embeddings:  13%|█▎        | 12/95 [00:10<01:53,  1.36s/it]
# Extracting embeddings:  14%|█▎        | 13/95 [00:11<01:33,  1.14s/it]
# Extracting embeddings:  15%|█▍        | 14/95 [00:12<01:28,  1.10s/it]
# Extracting embeddings:  16%|█▌        | 15/95 [00:12<01:18,  1.02it/s]
# Extracting embeddings:  17%|█▋        | 16/95 [00:13<01:11,  1.11it/s]
# Extracting embeddings:  18%|█▊        | 17/95 [00:14<01:02,  1.24it/s]
# Extracting embeddings:  19%|█▉        | 18/95 [00:15<01:06,  1.15it/s]
# Extracting embeddings:  20%|██        | 19/95 [00:16<01:10,  1.08it/s]
# Extracting embeddings:  21%|██        | 20/95 [00:16<01:02,  1.20it/s]
# Extracting embeddings:  22%|██▏       | 21/95 [00:17<01:02,  1.18it/s]
# Extracting embeddings:  23%|██▎       | 22/95 [00:18<00:55,  1.32it/s]
# Extracting embeddings:  24%|██▍       | 23/95 [00:19<00:56,  1.27it/s]
# Extracting embeddings:  25%|██▌       | 24/95 [00:20<01:07,  1.05it/s]
# Extracting embeddings:  26%|██▋       | 25/95 [00:21<01:00,  1.16it/s]
# Extracting embeddings:  27%|██▋       | 26/95 [00:22<01:02,  1.11it/s]
# Extracting embeddings:  28%|██▊       | 27/95 [00:22<01:01,  1.11it/s]
# Extracting embeddings:  29%|██▉       | 28/95 [00:23<00:53,  1.25it/s]
# Extracting embeddings:  31%|███       | 29/95 [00:24<00:51,  1.28it/s]
# Extracting embeddings:  32%|███▏      | 30/95 [00:24<00:47,  1.36it/s]
# Extracting embeddings:  33%|███▎      | 31/95 [00:25<00:45,  1.40it/s]
# Extracting embeddings:  34%|███▎      | 32/95 [00:26<00:42,  1.50it/s]
# Extracting embeddings:  35%|███▍      | 33/95 [00:26<00:41,  1.50it/s]
# Extracting embeddings:  36%|███▌      | 34/95 [00:27<00:43,  1.40it/s]
# Extracting embeddings:  37%|███▋      | 35/95 [00:28<00:49,  1.22it/s]
# Extracting embeddings:  38%|███▊      | 36/95 [00:29<00:42,  1.39it/s]
# Extracting embeddings:  39%|███▉      | 37/95 [00:31<01:03,  1.09s/it]
# Extracting embeddings:  40%|████      | 38/95 [00:31<00:58,  1.02s/it]
# Extracting embeddings:  41%|████      | 39/95 [00:33<01:03,  1.14s/it]
# Extracting embeddings:  42%|████▏     | 40/95 [00:33<00:53,  1.02it/s]
# Extracting embeddings:  43%|████▎     | 41/95 [00:34<00:47,  1.14it/s]
# Extracting embeddings:  44%|████▍     | 42/95 [00:36<01:01,  1.16s/it]
# Extracting embeddings:  45%|████▌     | 43/95 [00:36<00:48,  1.06it/s]
# Extracting embeddings:  46%|████▋     | 44/95 [00:37<00:50,  1.02it/s]
# Extracting embeddings:  47%|████▋     | 45/95 [00:38<00:46,  1.07it/s]
# Extracting embeddings:  48%|████▊     | 46/95 [00:39<00:39,  1.23it/s]
# Extracting embeddings:  49%|████▉     | 47/95 [00:39<00:36,  1.30it/s]
# Extracting embeddings:  51%|█████     | 48/95 [00:40<00:37,  1.24it/s]
# Extracting embeddings:  52%|█████▏    | 49/95 [00:42<00:55,  1.20s/it]
# Extracting embeddings:  53%|█████▎    | 50/95 [00:43<00:46,  1.03s/it]
# Extracting embeddings:  54%|█████▎    | 51/95 [00:44<00:39,  1.11it/s]
# Extracting embeddings:  55%|█████▍    | 52/95 [00:44<00:33,  1.30it/s]
# Extracting embeddings:  56%|█████▌    | 53/95 [00:45<00:33,  1.26it/s]
# Extracting embeddings:  57%|█████▋    | 54/95 [00:46<00:31,  1.28it/s]
# Extracting embeddings:  58%|█████▊    | 55/95 [00:46<00:27,  1.45it/s]
# Extracting embeddings:  59%|█████▉    | 56/95 [00:47<00:27,  1.41it/s]
# Extracting embeddings:  60%|██████    | 57/95 [00:48<00:24,  1.53it/s]
# Extracting embeddings:  61%|██████    | 58/95 [00:48<00:21,  1.71it/s]
# Extracting embeddings:  62%|██████▏   | 59/95 [00:49<00:20,  1.72it/s]
# Extracting embeddings:  63%|██████▎   | 60/95 [00:51<00:36,  1.04s/it]
# Extracting embeddings:  64%|██████▍   | 61/95 [00:51<00:30,  1.11it/s]
# Extracting embeddings:  65%|██████▌   | 62/95 [00:52<00:24,  1.33it/s]
# Extracting embeddings:  66%|██████▋   | 63/95 [00:53<00:29,  1.10it/s]
# Extracting embeddings:  67%|██████▋   | 64/95 [00:53<00:23,  1.34it/s]
# Extracting embeddings:  68%|██████▊   | 65/95 [00:54<00:20,  1.47it/s]
# Extracting embeddings:  69%|██████▉   | 66/95 [00:55<00:22,  1.26it/s]
# Extracting embeddings:  71%|███████   | 67/95 [00:55<00:19,  1.44it/s]
# Extracting embeddings:  72%|███████▏  | 68/95 [00:56<00:20,  1.29it/s]
# Extracting embeddings:  73%|███████▎  | 69/95 [00:57<00:18,  1.42it/s]
# Extracting embeddings:  74%|███████▎  | 70/95 [00:57<00:15,  1.61it/s]
# Extracting embeddings:  75%|███████▍  | 71/95 [00:58<00:13,  1.73it/s]
# Extracting embeddings:  76%|███████▌  | 72/95 [00:58<00:12,  1.80it/s]
# Extracting embeddings:  77%|███████▋  | 73/95 [00:59<00:11,  1.87it/s]
# Extracting embeddings:  78%|███████▊  | 74/95 [00:59<00:10,  1.97it/s]
# Extracting embeddings:  79%|███████▉  | 75/95 [01:00<00:11,  1.77it/s]
# Extracting embeddings:  80%|████████  | 76/95 [01:00<00:10,  1.81it/s]
# Extracting embeddings:  81%|████████  | 77/95 [01:01<00:09,  1.93it/s]
# Extracting embeddings:  82%|████████▏ | 78/95 [01:01<00:08,  1.93it/s]
# Extracting embeddings:  83%|████████▎ | 79/95 [01:02<00:09,  1.61it/s]
# Extracting embeddings:  84%|████████▍ | 80/95 [01:03<00:11,  1.36it/s]
# Extracting embeddings:  85%|████████▌ | 81/95 [01:04<00:09,  1.48it/s]
# Extracting embeddings:  86%|████████▋ | 82/95 [01:04<00:07,  1.69it/s]
# Extracting embeddings:  87%|████████▋ | 83/95 [01:05<00:07,  1.58it/s]
# Extracting embeddings:  88%|████████▊ | 84/95 [01:06<00:07,  1.53it/s]
# Extracting embeddings:  89%|████████▉ | 85/95 [01:06<00:05,  1.67it/s]
# Extracting embeddings:  91%|█████████ | 86/95 [01:06<00:04,  1.88it/s]
# Extracting embeddings:  92%|█████████▏| 87/95 [01:07<00:03,  2.05it/s]
# Extracting embeddings:  93%|█████████▎| 88/95 [01:07<00:03,  1.97it/s]
# Extracting embeddings:  94%|█████████▎| 89/95 [01:08<00:03,  1.95it/s]
# Extracting embeddings:  95%|█████████▍| 90/95 [01:09<00:03,  1.59it/s]
# Extracting embeddings:  96%|█████████▌| 91/95 [01:09<00:02,  1.58it/s]
# Extracting embeddings:  97%|█████████▋| 92/95 [01:10<00:01,  1.71it/s]
# Extracting embeddings:  98%|█████████▊| 93/95 [01:10<00:01,  1.88it/s]
# Extracting embeddings:  99%|█████████▉| 94/95 [01:11<00:00,  1.92it/s]
# Extracting embeddings: 100%|██████████| 95/95 [01:11<00:00,  1.33it/s]
# Extracting embeddings: 100%|██████████| 24/24 [00:21<00:00,  1.12it/s]

# %%
# Flatten labels for XGBoost (multi-label classification)
y_train_flat = np.array(y_train)
y_valid_flat = np.array(y_valid)

# %%
from sklearn.svm import SVC

# %%
svm_models = {}
predictions = {}

for i, label in enumerate(label_columns):
    print(f"Training SVM for label: {label}")

    # Use the computed class weights for balancing the classes
    class_weight = {0: 1, 1: class_weights_tensor[i].item()}  # Adjust the class weights

    svm_model = SVC(class_weight={0: 1, 1: class_weights_tensor[i].item()})

    svm_model.fit(x_train_embeddings, y_train_flat[:, i])
    svm_models[label] = svm_model

    # Predict on validation data
    predictions[label] = svm_model.predict(x_valid_embeddings)
# Out:
# Training SVM for label: anger
# Training SVM for label: disgust
# Training SVM for label: fear
# Training SVM for label: joy
# Training SVM for label: sadness
# Training SVM for label: surprise

# %%
# Evaluate the models
results = []
for i, label in enumerate(label_columns):
    precision, recall, f1, _ = precision_recall_fscore_support(
        y_valid_flat[:, i],
        predictions[label],
        average="binary"
    )
    accuracy = accuracy_score(y_valid_flat[:, i], predictions[label])
    results.append({
        "Label": label,
        "Precision": precision,
        "Recall": recall,
        "F1 Score": f1,
        "Accuracy": accuracy
    })

# %%
# Display evaluation results
results_df = pd.DataFrame(results)
print(results_df)
# Out:
#       Label  Precision    Recall  F1 Score  Accuracy
# 0     anger   0.647959  0.798742  0.715493  0.866225
# 1   disgust   0.282051  0.343750  0.309859  0.935099
# 2      fear   0.305085  0.450000  0.363636  0.916556
# 3       joy   0.708075  0.726115  0.716981  0.880795
# 4   sadness   0.606299  0.641667  0.623482  0.876821
# 5  surprise   0.300000  0.400000  0.342857  0.908609

# %%
print(f"{x} evaluates:")

for k, res in enumerate(results):

  print(f"Class '{res['Label']}': Precision: {res['Precision']:.4f}, Recall: {res['Recall']:.4f}, F1: {res['F1 Score']:.4f}")

print(f"Overall accuracy: {accuracy:.4f}")

print("-------------------------------------------------------------------------\n")
# Out:
# neuralmind/bert-large-portuguese-cased evaluates:
# Class 'anger': Precision: 0.6480, Recall: 0.7987, F1: 0.7155
# Class 'disgust': Precision: 0.2821, Recall: 0.3438, F1: 0.3099
# Class 'fear': Precision: 0.3051, Recall: 0.4500, F1: 0.3636
# Class 'joy': Precision: 0.7081, Recall: 0.7261, F1: 0.7170
# Class 'sadness': Precision: 0.6063, Recall: 0.6417, F1: 0.6235
# Class 'surprise': Precision: 0.3000, Recall: 0.4000, F1: 0.3429
# Overall accuracy: 0.9086
# -------------------------------------------------------------------------

# %%
# Initialize a DataFrame to store the evaluation results for each language
lang_metrics_df = pd.DataFrame(columns=["Language", "Precision", "Recall", "F1_score", "Accuracy"])

# Iterate over each language
for lang in langs:
    # Filter the validation data for the current language
    lang_valid_data = valid[valid['lang'] == lang]
    lang_x_valid = lang_valid_data['clean_message'].values.tolist()
    lang_y_valid = lang_valid_data[label_columns].values.tolist()

    if len(lang_valid_data) == 0:
        continue

    # Extract embeddings for the current language's validation data
    lang_x_valid_embeddings = extract_embeddings(lang_x_valid, embedding_model)
    print()
    # Initialize metrics storage
    all_precisions, all_recalls, all_f1_scores, all_accuracies = [], [], [], []

    # Evaluate each label separately
    for i, label in enumerate(label_columns):
        # Predict using the corresponding svm model
        lang_predictions = svm_models[label].predict(lang_x_valid_embeddings)

        # Compute metrics
        precision, recall, f1, _ = precision_recall_fscore_support(
            np.array(lang_y_valid)[:, i],  # True labels for this label
            lang_predictions,
            average="binary",
            zero_division=0
        )
        accuracy = accuracy_score(np.array(lang_y_valid)[:, i], lang_predictions)

        # Store metrics
        all_precisions.append(precision)
        all_recalls.append(recall)
        all_f1_scores.append(f1)
        all_accuracies.append(accuracy)

    # Aggregate metrics (average across all labels for the language)
    new_data = pd.DataFrame({
        "Language": [lang],
        "Precision": [np.mean(all_precisions)],
        "Recall": [np.mean(all_recalls)],
        "F1_score": [np.mean(all_f1_scores)],
        "Accuracy": [np.mean(all_accuracies)]
    })

    lang_metrics_df = pd.concat([lang_metrics_df, new_data], ignore_index=True)

# Display the evaluation results for each language
print(lang_metrics_df)
# Out:
# Extracting embeddings: 100%|██████████| 15/15 [00:15<00:00,  1.05s/it]
# <ipython-input-314-9b6d3eac4dcb>:49: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   lang_metrics_df = pd.concat([lang_metrics_df, new_data], ignore_index=True)
# Extracting embeddings: 100%|██████████| 10/10 [00:02<00:00,  4.30it/s]
#   Language  Precision    Recall  F1_score  Accuracy
# 0     ptbr   0.466944  0.577351  0.511676  0.889625
# 1     ptmz   0.410782  0.412316  0.398036  0.908940

# %%
import pickle
# Save the svm models if needed
for label, model in svm_models.items():
    with open(f"svm_model_{label}.pkl", 'wb') as f:
      pickle.dump(model, f)

# %%
# !zip svm_models_pkl.zip svm_model_*.pkl
# Out:
# updating: svm_model_anger.pkl (deflated 75%)
# updating: svm_model_disgust.pkl (deflated 75%)
# updating: svm_model_fear.pkl (deflated 75%)
# updating: svm_model_joy.pkl (deflated 75%)
# updating: svm_model_sadness.pkl (deflated 75%)
# updating: svm_model_surprise.pkl (deflated 75%)
